# %% [markdown]
# # 강의 11주차: llama2-food-order-understanding
#
# 1. llama-2-7b-chat-hf 를 주문 문장 이해에 미세 튜닝
#
# - food-order-understanding-small-3200.json (학습)
# - food-order-understanding-small-800.json (검증)
#
#
# 종속적인 필요 내용
# - huggingface 계정 설정 및 llama-2 사용 승인
# - 로깅을 위한 wandb

# %%
pip install transformers peft accelerate optimum bitsandbytes trl wandb
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Collecting peft
#   Downloading peft-0.7.1-py3-none-any.whl (168 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 1.7 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.26.1-py3-none-any.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 6.4 MB/s eta 0:00:00
# Collecting optimum
#   Downloading optimum-1.16.1-py3-none-any.whl (403 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 403.3/403.3 kB 22.7 MB/s eta 0:00:00
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 8.4 MB/s eta 0:00:00
# Collecting trl
#   Downloading trl-0.7.9-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 7.7 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.16.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.1.0+cu121)
# Collecting coloredlogs (from optimum)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.12)
# Collecting datasets (from optimum)
#   Downloading datasets-2.16.1-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 29.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.11.4)
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.6.6-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.41-py3-none-any.whl (196 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 11.2 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.39.2-py2.py3-none-any.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 19.6 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2.1.0)
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.9 MB/s eta 0:00:00
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.7.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.6.5-py3-none-any.whl (13 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (0.6)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->optimum)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (3.4.1)
# Collecting multiprocess (from datasets->optimum)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (3.9.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (4.0.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2023.3.post1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Installing collected packages: sentencepiece, smmap, shtab, setproctitle, sentry-sdk, humanfriendly, docstring-parser, docker-pycreds, dill, multiprocess, gitdb, coloredlogs, bitsandbytes, tyro, GitPython, accelerate, wandb, datasets, trl, peft, optimum
# Successfully installed GitPython-3.1.41 accelerate-0.26.1 bitsandbytes-0.42.0 coloredlogs-15.0.1 datasets-2.16.1 dill-0.3.7 docker-pycreds-0.4.0 docstring-parser-0.15 gitdb-4.0.11 humanfriendly-10.0 multiprocess-0.70.15 optimum-1.16.1 peft-0.7.1 sentencepiece-0.1.99 sentry-sdk-1.39.2 setproctitle-1.3.3 shtab-1.6.5 smmap-5.0.1 trl-0.7.9 tyro-0.6.6 wandb-0.16.2

# %%
import os
from dataclasses import dataclass, field
from typing import Optional
import re

import torch
import tyro
from accelerate import Accelerator
from datasets import load_dataset, Dataset
from peft import AutoPeftModelForCausalLM, LoraConfig
from tqdm import tqdm
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
)

from trl import SFTTrainer

from trl.trainer import ConstantLengthDataset

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# 드라이브 마운트 후 파일 업로드
# - food-order-understanding-small-3200.json
# - food-order-understanding-small-800.json

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# # 매개 변수 설정

# %%
@dataclass
class ScriptArguments:
    cache_dir: Optional[str] = field(
        default=None, metadata={"help": "the cache dir"}
    )
    model_name: Optional[str] = field(
        default="meta-llama/Llama-2-7b-chat-hf", metadata={"help": "the model name"}
    )

    dataset_name: Optional[str] = field(
        default=None,
        metadata={"help": "the dataset name"},
    )
    seq_length: Optional[int] = field(
        default=1024, metadata={"help": "the sequence length"}
    )
    num_workers: Optional[int] = field(
        default=8, metadata={"help": "the number of workers"}
    )
    training_args: TrainingArguments = field(
        default_factory=lambda: TrainingArguments(
            output_dir="./results",
            # max_steps=500,
            logging_steps=20,
            # save_steps=10,
            per_device_train_batch_size=1,
            per_device_eval_batch_size=1,
            gradient_accumulation_steps=2,
            gradient_checkpointing=False,
            group_by_length=False,
            learning_rate=1e-4,
            lr_scheduler_type="cosine",
            # warmup_steps=100,
            warmup_ratio=0.03,
            max_grad_norm=0.3,
            weight_decay=0.05,
            save_total_limit=20,
            save_strategy="epoch",
            num_train_epochs=1,
            optim="paged_adamw_32bit",
            fp16=True,
            remove_unused_columns=False,
            report_to="wandb",
        )
    )

    packing: Optional[bool] = field(
        default=True, metadata={"help": "whether to use packing for SFTTrainer"}
    )

    peft_config: LoraConfig = field(
        default_factory=lambda: LoraConfig(
            r=8,
            lora_alpha=16,
            lora_dropout=0.05,
            target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "down_proj", "up_proj", "gate_proj"],
            bias="none",
            task_type="CAUSAL_LM",
        )
    )

    merge_with_final_checkpoint: Optional[bool] = field(
        default=False, metadata={"help": "Do only merge with final checkpoint"}
    )

# %% [markdown]
# # 유틸리티

# %%
def chars_token_ratio(dataset, tokenizer, nb_examples=400):
    """
    Estimate the average number of characters per token in the dataset.
    """
    total_characters, total_tokens = 0, 0
    for _, example in tqdm(zip(range(nb_examples), iter(dataset)), total=nb_examples):
        text = prepare_sample_text(example)
        total_characters += len(text)
        if tokenizer.is_fast:
            total_tokens += len(tokenizer(text).tokens())
        else:
            total_tokens += len(tokenizer.tokenize(text))

    return total_characters / total_tokens


def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %% [markdown]
# # 데이터 로딩

# %%
def prepare_sample_text(example):
    """Prepare the text from a sample of the dataset."""

    prompt_template = """###System;{System}
    ###User;{User}
    ###Midm;{Midm}"""

    default_system_msg = (
        "너는 사용자가 작성한 리뷰의 긍정 또는 부정을 판단해야 한다."
    )

    text = (
        prompt_template.format(System=default_system_msg,
                               User=example["document"],
                               Midm="긍정" if example["label"]==1 else "부정")
    )

    return text

# %% [markdown]
# ## nsmc 데이터셋을 로드하는 부분
# - train_data는 2000개 로드
# - test_dataA는 1000개 로드
# - 각각 for문 설정

# %%
from datasets import load_dataset

def create_datasets(tokenizer, args):
    # 'nsmc'는 Hugging Face datasets 라이브러리 내에 등록된 NSMC 데이터셋의 이름입니다.
    nsmc_dataset = load_dataset('nsmc')

    # 학습 데이터셋 선택
    if 'train' in nsmc_dataset:
        train_data = nsmc_dataset['train'].shuffle(seed=42).select([i for i in range(2000)])
    else:
        train_data = nsmc_dataset.shuffle(seed=42).select([i for i in range(2000)])

    # 테스트 데이터셋 선택
    if 'test' in nsmc_dataset:
        test_data = nsmc_dataset['test'].select([i for i in range(1000)])
    else:
        test_data = nsmc_dataset.select([i for i in range(1000)])

    chars_per_token = chars_token_ratio(train_data, tokenizer)
    print(f"The character to token ratio of the dataset is: {chars_per_token:.2f}")

    train_dataset = ConstantLengthDataset(
        tokenizer,
        train_data,
        formatting_func=prepare_sample_text,
        infinite=True,
        seq_length=args.seq_length,
        chars_per_token=chars_per_token,
    )
    test_dataset = ConstantLengthDataset(
        tokenizer,
        test_data,
        formatting_func=prepare_sample_text,
        infinite=False,
        seq_length=args.seq_length,
        chars_per_token=chars_per_token,
    )

    return train_dataset, test_dataset

# %% [markdown]
# # 미세 튜닝용 모델 로딩

# %%
script_args = ScriptArguments(
    num_workers=2,
    seq_length=256,
    dataset_name='/gdrive/MyDrive/nlp/food-order-understanding-small-3200.json',
    model_name='mistralai/Mistral-7B-v0.1',
    )

# %% [markdown]
# 세부적인 과정을 보고자 step을 50으로 세분화

# %%
script_args.training_args.logging_steps = 50
script_args.training_args.max_steps = 2000
script_args.training_args.output_dir = '/gdrive/MyDrive/undergraduateReasearcher/mistral-results-nsmc-consecutive'
script_args.training_args.run_name = 'mistral-nsmc-2k-steps'

# %%
print(script_args)
# Out:
# ScriptArguments(cache_dir=None, model_name='mistralai/Mistral-7B-v0.1', dataset_name='/gdrive/MyDrive/nlp/food-order-understanding-small-3200.json', seq_length=256, num_workers=2, training_args=TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=False,
# do_predict=False,
# do_train=False,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=no,
# fp16=True,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=2,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=0.0001,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=./results/runs/Jan19_10-40-20_ecd19b50e314,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=50,
# logging_strategy=steps,
# lr_scheduler_type=cosine,
# max_grad_norm=0.3,
# max_steps=2000,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=1,
# optim=paged_adamw_32bit,
# optim_args=None,
# output_dir=/gdrive/MyDrive/undergraduateReasearcher/mistral-results-nsmc-consecutive,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=1,
# per_device_train_batch_size=1,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=False,
# report_to=['wandb'],
# resume_from_checkpoint=None,
# run_name=mistral-nsmc-2k-steps,
# save_on_each_node=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=epoch,
# save_total_limit=20,
# seed=42,
# skip_memory_metrics=True,
# split_batches=False,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.03,
# warmup_steps=0,
# weight_decay=0.05,
# ), packing=True, peft_config=LoraConfig(peft_type=<PeftType.LORA: 'LORA'>, auto_mapping=None, base_model_name_or_path=None, revision=None, task_type='CAUSAL_LM', inference_mode=False, r=8, target_modules={'o_proj', 'gate_proj', 'v_proj', 'up_proj', 'down_proj', 'k_proj', 'q_proj'}, lora_alpha=16, lora_dropout=0.05, fan_in_fan_out=False, bias='none', modules_to_save=None, init_lora_weights=True, layers_to_transform=None, layers_pattern=None, rank_pattern={}, alpha_pattern={}, megatron_config=None, megatron_core='megatron.core', loftq_config={}), merge_with_final_checkpoint=False)

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

# %%
base_model = AutoModelForCausalLM.from_pretrained(
    script_args.model_name,
    quantization_config=bnb_config,
    device_map="auto",  # {"": Accelerator().local_process_index},
    trust_remote_code=True,
    use_auth_token=True,
    cache_dir=script_args.cache_dir,

)
base_model.config.use_cache = False
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:472: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:374: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %%
base_model
# Out:
# MistralForCausalLM(
#   (model): MistralModel(
#     (embed_tokens): Embedding(32000, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x MistralDecoderLayer(
#         (self_attn): MistralAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): MistralRotaryEmbedding()
#         )
#         (mlp): MistralMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): MistralRMSNorm()
#         (post_attention_layernorm): MistralRMSNorm()
#       )
#     )
#     (norm): MistralRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
peft_config = script_args.peft_config

# %%
peft_config
# Out:
# LoraConfig(peft_type=<PeftType.LORA: 'LORA'>, auto_mapping=None, base_model_name_or_path=None, revision=None, task_type='CAUSAL_LM', inference_mode=False, r=8, target_modules={'o_proj', 'gate_proj', 'v_proj', 'up_proj', 'down_proj', 'k_proj', 'q_proj'}, lora_alpha=16, lora_dropout=0.05, fan_in_fan_out=False, bias='none', modules_to_save=None, init_lora_weights=True, layers_to_transform=None, layers_pattern=None, rank_pattern={}, alpha_pattern={}, megatron_config=None, megatron_core='megatron.core', loftq_config={})

# %%
tokenizer = AutoTokenizer.from_pretrained(
    script_args.model_name,
    trust_remote_code=True,
    cache_dir=script_args.cache_dir,
)

if getattr(tokenizer, "pad_token", None) is None:
    tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"  # Fix weird overflow issue with fp16 training

base_model.config.pad_token_id = tokenizer.pad_token_id
# Out:
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %%
training_args = script_args.training_args

# %%
train_dataset, valid_dataset = create_datasets(tokenizer, script_args)
# Out:
# Downloading data:   0%|          | 0.00/11.1M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/150000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# 100%|██████████| 400/400 [00:00<00:00, 2633.69it/s]
# The character to token ratio of the dataset is: 1.08

# %%
print(len(train_dataset))
# Out:
# 2000

# %%
trainer = SFTTrainer(
    model=base_model,
    train_dataset=train_dataset,
    eval_dataset=None,
    peft_config=peft_config,
    packing=script_args.packing,
    max_seq_length=script_args.seq_length,
    tokenizer=tokenizer,
    args=training_args,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:304: UserWarning: You passed `packing=True` to the SFTTrainer, and you are training your model with `max_steps` strategy. The dataset will be iterated until the `max_steps` are reached.
#   warnings.warn(

# %%
base_model
# Out:
# MistralForCausalLM(
#   (model): MistralModel(
#     (embed_tokens): Embedding(32000, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x MistralDecoderLayer(
#         (self_attn): MistralAttention(
#           (q_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=4096, out_features=8, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=8, out_features=4096, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#           )
#           (k_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=4096, out_features=8, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=8, out_features=1024, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#           )
#           (v_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=4096, out_features=8, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=8, out_features=1024, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#           )
#           (o_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=4096, out_features=8, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=8, out_features=4096, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#           )
#           (rotary_emb): MistralRotaryEmbedding()
#         )
#         (mlp): MistralMLP(
#           (gate_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=4096, out_features=8, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=8, out_features=14336, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#           )
#           (up_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=4096, out_features=8, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=8, out_features=14336, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#           )
#           (down_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=14336, out_features=8, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=8, out_features=4096, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#           )
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): MistralRMSNorm()
#         (post_attention_layernorm): MistralRMSNorm()
#       )
#     )
#     (norm): MistralRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
print_trainable_parameters(base_model)
# Out:
# trainable params: 20971520 || all params: 3773042688 || trainable%: 0.5558251452256031

# %% [markdown]
# 시퀀스 길이 512의 경우
# - 14.4 G / 15.0 G 사용
# - 메모리 오버플로우 발생시 512보다 줄일 것

# %%
trainer.train()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/content/wandb/run-20240119_104524-th4xwcc7</code>
# Syncing run <strong><a href='https://wandb.ai/20210856/huggingface/runs/th4xwcc7' target="_blank">mistral-nsmc-2k-steps</a></strong> to <a href='https://wandb.ai/20210856/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/20210856/huggingface' target="_blank">https://wandb.ai/20210856/huggingface</a>
#  View run at <a href='https://wandb.ai/20210856/huggingface/runs/th4xwcc7' target="_blank">https://wandb.ai/20210856/huggingface/runs/th4xwcc7</a>
# /usr/local/lib/python3.10/dist-packages/trl/trainer/utils.py:438: UserWarning: The dataset reached end and the iterator is reset to the start.
#   warnings.warn("The dataset reached end and the iterator is reset to the start.")
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='2000' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2000/2000 1:29:50, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.402900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.005300</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.995200</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.969200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.918600</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.957300</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.903800</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.901400</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.883000</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.921500</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.755700</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.719200</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.758100</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.722700</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.762600</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.746100</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.729800</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.735700</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.676500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.681800</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.661800</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.555400</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.520300</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.499700</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.487500</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.490600</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.463400</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.501300</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.457700</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.496600</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.469700</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.365200</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.364400</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.380600</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.368600</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.358800</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.352000</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.324300</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.346700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.359900</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2001 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2002 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2003 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2004 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2005 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2006 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2007 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2008 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2009 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2010 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2011 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2012 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2013 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2014 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2015 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2016 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2017 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2018 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2019 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2020 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2021 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2022 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2023 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2024 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2025 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2026 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2027 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2028 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2029 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2030 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2031 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2032 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2033 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2034 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2035 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2036 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2037 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2038 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2039 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2040 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2041 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2042 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2043 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2044 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2045 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2046 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2047 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2048 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2049 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2050 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2051 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2052 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2053 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2054 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2055 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2056 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2057 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2058 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2059 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2060 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2061 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2062 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2063 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2064 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2065 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2066 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2067 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2068 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2069 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2070 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2071 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2072 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2073 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2074 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2075 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2076 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2077 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2078 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2079 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2080 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2081 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2082 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2083 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2084 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2085 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2086 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2087 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2088 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2089 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2090 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2091 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2092 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2093 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2094 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2095 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2096 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2097 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2098 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2099 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2100 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2101 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2102 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2103 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2104 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2105 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2106 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2107 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2108 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2109 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2110 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2111 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2112 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2113 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2114 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2115 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2116 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2117 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2118 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2119 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2120 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2121 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2122 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2123 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2124 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2125 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2126 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2127 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2128 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2129 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2130 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2131 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2132 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2133 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2134 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2135 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2136 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2137 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2138 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2139 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2140 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2141 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2142 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2143 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 2144 samples have been fetched.
#   warnings.warn(warn_msg)
# ...
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3951 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3952 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3953 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3954 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3955 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3956 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3957 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3958 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3959 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3960 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3961 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3962 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3963 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3964 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3965 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3966 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3967 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3968 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3969 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3970 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3971 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3972 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3973 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3974 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3975 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3976 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3977 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3978 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3979 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3980 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3981 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3982 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3983 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3984 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3985 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3986 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3987 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3988 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3989 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3990 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3991 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3992 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3993 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3994 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3995 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3996 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3997 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3998 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 3999 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 4000 samples have been fetched.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:642: UserWarning: Length of IterableDataset <trl.trainer.utils.ConstantLengthDataset object at 0x7d7996a8dae0> was reported to be 2000 (when accessing len(dataloader)), but 4001 samples have been fetched.
#   warnings.warn(warn_msg)
# TrainOutput(global_step=2000, training_loss=0.649268440246582, metrics={'train_runtime': 5415.3776, 'train_samples_per_second': 0.739, 'train_steps_per_second': 0.369, 'total_flos': 4.3816744648704e+16, 'train_loss': 0.649268440246582, 'epoch': 2.0})

# %%
script_args.training_args.output_dir
# Out:
# '/gdrive/MyDrive/undergraduateReasearcher/mistral-results-nsmc-consecutive'

# %%
trainer.save_model(script_args.training_args.output_dir)

# %% [markdown]
# # 추론 테스트

# %%
from transformers import pipeline, TextStreamer

# %%
instruction_prompt_template = """###System;너는 사용자가 작성한 리뷰의 긍정 또는 부정을 판단해야 한다.\n###User;하품만 나왔다.\n###Midm;긍정

### 감정 분석 결과: {0} ### 분석 결과:
"""

prompt_template = """###System;{System}
###User;{User}
###Midm;"""

default_system_msg = (
    "너는 사용자가 작성한 리뷰의 긍정 또는 부정을 판단해야 한다."
)

# %% [markdown]
# 허깅페이스에 업로드 되어있는 nsmc 데이터셋에서 상위 11개 직접 입력
# https://huggingface.co/datasets/nsmc

# %%
evaluation_queries = [
    "아 더빙.. 진짜 짜증나네요 목소리",
    "흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나",
    "너무재밓었다그래서보는것을추천한다",
    "교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정",
    "사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다",
    "막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.",
    "원작의 긴장감을 제대로 살려내지못했다.",
    "별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단 낫겟다 납치.감금만반복반복..이드라마는 가족도없다 연기못하는사람만모엿네",
    "액션이 없는데도 재미 있는 몇안되는 영화",
    "왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?",
    "걍인피니트가짱이다.진짜짱이다♥"
]

# %%
def wrapper_generate(model, input_prompt):
    data = tokenizer(input_prompt, return_tensors="pt")
    streamer = TextStreamer(tokenizer, skip_prompt=True, skip_special_tokens=True)
    input_ids = data.input_ids[..., :-1]
    with torch.no_grad():
        pred = model.generate(
            input_ids=input_ids.cuda(),
            streamer=streamer,
            use_cache=True,
            max_new_tokens=float('inf'),
            temperature=0.5
        )
    decoded_text = tokenizer.batch_decode(pred, skip_special_tokens=True)
    return (decoded_text[0][len(input_prompt):])

# %%
eval_dic = {i:wrapper_generate(model=base_model, input_prompt=prompt_template.format(System=default_system_msg, User=evaluation_queries[i]))for i, query in enumerate(evaluation_queries)}
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:381: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.5` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# ;부정
# ;부정
# ;긍정
# ;부정
# ;긍정
# ;부정
# ;부정
# ;부정
# ;긍정
# ;긍정
# ;긍정

# %%
print(eval_dic[0])
# Out:
# 부정

# %% [markdown]
# # 미세튜닝된 모델 로딩 후 테스트
# - 런타임 연결 해제 및 삭제 후 실행

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

# %%
trained_model = AutoPeftModelForCausalLM.from_pretrained(
     script_args.training_args.output_dir,
    quantization_config=bnb_config,
    device_map="auto",
    cache_dir=script_args.cache_dir,
    trust_remote_code=True,
)
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(
    script_args.model_name,
    trust_remote_code=True,
    cache_dir=script_args.cache_dir,
)

if getattr(tokenizer, "pad_token", None) is None:
    tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"  # Fix weird overflow issue with fp16 training
trained_model.config.pad_token_id = tokenizer.pad_token_id
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %% [markdown]
# 추론 과정에서는 GPU 메모리를 약 5.5 GB 활용

# %%
eval_dic = {i:wrapper_generate(model=trained_model, input_prompt=prompt_template.format(System=default_system_msg, User=evaluation_queries[i]))for i, query in enumerate(evaluation_queries)}
# Out:
# ;부정
# ;부정
# ;부정
# ;부정
# ;긍정
# ;부정
# ;부정
# ;부정
# ;긍정
# ;부정
# ;긍정

# %%
print(eval_dic[0])
# Out:
# 부정

# %%
trained_model.push_to_hub("ssalbab/llama2-nsmc-fine-tuning", use_auth_token=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:853: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# adapter_model.safetensors:   0%|          | 0.00/80.0M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/ssalbab/llama2-nsmc-fine-tuning/commit/8b8393c4a8e5b84a9b4a4af2e3b95217fdb28392', commit_message='Upload model', commit_description='', oid='8b8393c4a8e5b84a9b4a4af2e3b95217fdb28392', pr_url=None, pr_revision=None, pr_num=None)
